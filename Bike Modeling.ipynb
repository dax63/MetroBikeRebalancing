# %%
import pandas as pd
import numpy as np

import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.dummy import DummyClassifier

import xgboost as xgb

# %%
'''
conda activate catboost_env
conda install scikit-learn
jupyter notebook
'''

# %%
import catboost
from catboost import CatBoostClassifier

# %%
# Import Dataframes

# %%
checkout_df = pd.read_csv('checkout_df.csv', index_col = 0)
return_df = pd.read_csv('return_df.csv', index_col = 0)

# %%
checkout_df = checkout_df.drop('outgoing_bikes_count', axis=1)
return_df = return_df.drop('incoming_bikes_count', axis=1)

# %%
# Variable preparation for modeling

# %%
# season variable encoding
def map_seasons(df, column_name):
    season_mapping = {
        'winter': 0,
        'spring': 1,
        'summer': 2,
        'fall': 3
    }
    
    df[column_name] = df[column_name].map(season_mapping)
    return df

map_seasons(return_df, 'season')
map_seasons(checkout_df, 'season')

# time variable splitting
def time_preprocess(df, column_name):
    df['hour'] = df[column_name].apply(lambda x: int(x.split(':')[0]))
    df['minute'] = df[column_name].apply(lambda x: int(x.split(':')[1]))
    df.drop(columns=[column_name], inplace=True)
    return df

time_preprocess(return_df, 'stoptime')
time_preprocess(checkout_df, 'starttime')
# Out:
#         Checkout Kiosk ID  Year  season  day  demand  hour  minute
# 0                     0.0  2022       3    0     Low     8      15
# 1                     0.0  2022       3    0  Medium     9      45
# 2                     0.0  2022       3    0  Medium    10       0
# 3                     0.0  2022       3    0     Low    10      30
# 4                     0.0  2022       3    0  Medium    11       0
# ...                   ...   ...     ...  ...     ...   ...     ...
# 491657             4879.0  2023       0    6     Low    19      45
# 491658             4879.0  2023       0    6     Low    20       0
# 491659             4879.0  2023       0    6  Medium    20      30
# 491660             4879.0  2023       0    6     Low    20      45
# 491661             4879.0  2023       0    6     Low    22      15
#
# [491662 rows x 7 columns]

# %%
return_df
# Out:
#         Return Kiosk ID  Year  season  day  demand  hour  minute
# 0                   0.0  2022       3    0     Low     4       0
# 1                   0.0  2022       3    0     Low     8      45
# 2                   0.0  2022       3    0     Low     9      45
# 3                   0.0  2022       3    0  Medium    11      45
# 4                   0.0  2022       3    0  Medium    12       0
# ...                 ...   ...     ...  ...     ...   ...     ...
# 532836           4879.0  2023       0    6     Low    20      15
# 532837           4879.0  2023       0    6     Low    20      30
# 532838           4879.0  2023       0    6     Low    20      45
# 532839           4879.0  2023       0    6     Low    21      30
# 532840           4879.0  2023       0    6     Low    22      15
#
# [532841 rows x 7 columns]

# %%
# Checkout modeling

# %%
# Get X and Y
c_x = checkout_df.drop(columns=['demand']) # features
c_y = checkout_df['demand'] # target

# %%
# Random Forest Classifier

# %%
from joblib import dump
# set up and train model
x_train, x_test, y_train, y_test = train_test_split(c_x, c_y, test_size=0.2, random_state=42)
checkout_rfc = RandomForestClassifier(n_estimators=50, max_depth=10, random_state = 0, verbose=True, n_jobs=-1)
checkout_rfc.fit(x_train, y_train)
dump(rfc, 'Models/rfc_checkout.joblib') 

# test model
y_prediction = checkout_rfc.predict(x_test)

# assess model performance
checkout_performance = classification_report(y_test, y_prediction)
print(checkout_performance)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    4.3s finished
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 6
#       4 checkout_rfc = RandomForestClassifier(n_estimators=50, max_depth=10, random_state = 0, verbose=True, n_jobs=-1)
#       5 checkout_rfc.fit(x_train, y_train)
# ----> 6 dump(rfc, 'Models/rfc_checkout.joblib')
#       8 # test model
#       9 y_prediction = checkout_rfc.predict(x_test)
#
# File ~/anaconda3/envs/catboost_env/lib/python3.9/site-packages/joblib/numpy_pickle.py:552, in dump(value, filename, compress, protocol, cache_size)
#     550         NumpyPickler(f, protocol=protocol).dump(value)
#     551 elif is_filename:
# --> 552     with open(filename, 'wb') as f:
#     553         NumpyPickler(f, protocol=protocol).dump(value)
#     554 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Models/rfc_checkout.joblib'

# %%
from sklearn.model_selection import cross_val_score

# Create a RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=50, max_depth=10, random_state = 0, verbose=True, n_jobs=-1)

# Perform 5-fold cross-validation and compute accuracy scores
accuracy_scores = cross_val_score(rfc, c_x, c_y, cv=5, scoring='accuracy')

# Calculate average accuracy
average_accuracy = accuracy_scores.mean()

print("Average Accuracy:", average_accuracy)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    8.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    8.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    9.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    9.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    9.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# Average Accuracy: 0.36959128287806814
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    0.3s finished

# %%
# XGBoost Classifier

# %%
# Get X and Y
c_x = checkout_df.drop(columns=['demand'])  # features
c_y = checkout_df['demand']  # target 

# Create a label-to-number mapping
label_mapping = {'High': 0, 'Low': 1, 'Medium': 2}

# Convert labels to numerical format
c_y_encoded = c_y.map(label_mapping)

# set up and train model
x_train, x_test, y_train, y_test = train_test_split(c_x, c_y_encoded, test_size=0.2, random_state=42)
xgb_model = xgb.XGBClassifier(random_state=0, verbosity=1, n_jobs=-1, max_depth=3, n_estimators=50)
xgb_model.fit(x_train, y_train)

# test model
y_prediction = xgb_model.predict(x_test)

# assess model performance
checkout_performance = classification_report(y_test, y_prediction)
print(checkout_performance)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.59      0.60     29596
#            1       0.54      0.60      0.57     35307
#            2       0.41      0.36      0.39     33430
#
#     accuracy                           0.52     98333
#    macro avg       0.52      0.52      0.52     98333
# weighted avg       0.51      0.52      0.51     98333

# %%
# Create a RandomForestClassifier
xgb_model = xgb.XGBClassifier(random_state=0, verbosity=1, n_jobs=-1, max_depth=3, n_estimators=50)
# Perform 5-fold cross-validation and compute accuracy scores
accuracy_scores = cross_val_score(xgb_model, c_x, c_y_encoded, cv=5, scoring='accuracy')

# Calculate average accuracy
average_accuracy = accuracy_scores.mean()

print("Average Accuracy:", average_accuracy)
# Out:
# Average Accuracy: 0.3439395958923089

# %%
# Catboost Classifier

# %%
# Get X and Y
c_x = checkout_df.drop(columns=['demand']) # features
c_y = checkout_df['demand'] # target 

# set up and train model
x_train, x_test, y_train, y_test = train_test_split(c_x, c_y, test_size=0.2, random_state=42)
catboost_model = CatBoostClassifier(random_state=0, verbose=1, thread_count=-1, max_depth=3, n_estimators=50)
catboost_model.fit(x_train, y_train)

# test model
y_prediction = catboost_model.predict(x_test)

# assess model performance
# 46:	learn: 0.9475627	total: 1.64s	remaining: 104ms
# 47:	learn: 0.9471730	total: 1.67s	remaining: 69.5ms
# 48:	learn: 0.9468331	total: 1.71s	remaining: 34.8ms
# 49:	learn: 0.9463597	total: 1.74s	remaining: 0us
#               precision    recall  f1-score   support
#
#         High       0.59      0.62      0.60     29596
#          Low       0.54      0.60      0.57     35307
#       Medium       0.41      0.35      0.38     33430
#
#     accuracy                           0.52     98333
#    macro avg       0.51      0.52      0.52     98333
# weighted avg       0.51      0.52      0.51     98333

# %%
# Create a RandomForestClassifier
catboost_model = CatBoostClassifier(random_state=0, verbose=1, thread_count=-1, max_depth=3, n_estimators=50)
# Perform 5-fold cross-validation and compute accuracy scores
accuracy_scores = cross_val_score(catboost_model, c_x, c_y, cv=5, scoring='accuracy')

# Calculate average accuracy
average_accuracy = accuracy_scores.mean()

print("Average Accuracy:", average_accuracy)
# Out:
# Learning rate set to 0.5
# 0:	learn: 1.0668163	total: 50.6ms	remaining: 2.48s
# 1:	learn: 1.0478620	total: 80.9ms	remaining: 1.94s
# 2:	learn: 1.0368131	total: 112ms	remaining: 1.75s
# 3:	learn: 1.0281977	total: 154ms	remaining: 1.77s
# 4:	learn: 1.0187529	total: 202ms	remaining: 1.82s
# 5:	learn: 1.0113421	total: 242ms	remaining: 1.78s
# 6:	learn: 1.0019025	total: 278ms	remaining: 1.71s
# 7:	learn: 0.9973519	total: 309ms	remaining: 1.62s
# 8:	learn: 0.9936338	total: 341ms	remaining: 1.55s
# 9:	learn: 0.9898003	total: 385ms	remaining: 1.54s
# 10:	learn: 0.9854947	total: 426ms	remaining: 1.51s
# 11:	learn: 0.9831001	total: 462ms	remaining: 1.46s
# 12:	learn: 0.9799690	total: 506ms	remaining: 1.44s
# 13:	learn: 0.9782551	total: 543ms	remaining: 1.4s
# 14:	learn: 0.9761079	total: 576ms	remaining: 1.34s
# 15:	learn: 0.9734047	total: 613ms	remaining: 1.3s
# 16:	learn: 0.9715636	total: 651ms	remaining: 1.26s
# 17:	learn: 0.9669742	total: 695ms	remaining: 1.23s
# 18:	learn: 0.9634812	total: 732ms	remaining: 1.2s
# 19:	learn: 0.9621638	total: 770ms	remaining: 1.15s
# 20:	learn: 0.9606163	total: 804ms	remaining: 1.11s
# 21:	learn: 0.9594440	total: 841ms	remaining: 1.07s
# 22:	learn: 0.9585907	total: 875ms	remaining: 1.03s
# 23:	learn: 0.9573873	total: 922ms	remaining: 999ms
# 24:	learn: 0.9562305	total: 956ms	remaining: 956ms
# 25:	learn: 0.9539235	total: 991ms	remaining: 915ms
# 26:	learn: 0.9532592	total: 1.02s	remaining: 871ms
# 27:	learn: 0.9512643	total: 1.06s	remaining: 830ms
# 28:	learn: 0.9496845	total: 1.1s	remaining: 794ms
# 29:	learn: 0.9482441	total: 1.13s	remaining: 757ms
# 30:	learn: 0.9473480	total: 1.17s	remaining: 718ms
# 31:	learn: 0.9463945	total: 1.21s	remaining: 680ms
# 32:	learn: 0.9457407	total: 1.25s	remaining: 641ms
# 26:	learn: 0.9534071	total: 926ms	remaining: 789ms
# 27:	learn: 0.9523127	total: 957ms	remaining: 752ms
# 28:	learn: 0.9507838	total: 990ms	remaining: 717ms
# 29:	learn: 0.9499996	total: 1.02s	remaining: 683ms
# 30:	learn: 0.9492772	total: 1.06s	remaining: 650ms
# 31:	learn: 0.9486402	total: 1.1s	remaining: 618ms
# 32:	learn: 0.9460027	total: 1.13s	remaining: 582ms
# 33:	learn: 0.9455126	total: 1.17s	remaining: 550ms
# 34:	learn: 0.9446698	total: 1.2s	remaining: 514ms
# 35:	learn: 0.9442122	total: 1.23s	remaining: 479ms
# 36:	learn: 0.9423620	total: 1.27s	remaining: 445ms
# 37:	learn: 0.9419529	total: 1.31s	remaining: 413ms
# 38:	learn: 0.9414125	total: 1.34s	remaining: 379ms
# 39:	learn: 0.9406261	total: 1.38s	remaining: 345ms
# 40:	learn: 0.9403427	total: 1.42s	remaining: 312ms
# 41:	learn: 0.9399484	total: 1.45s	remaining: 276ms
# 42:	learn: 0.9394317	total: 1.49s	remaining: 242ms
# 43:	learn: 0.9388340	total: 1.52s	remaining: 208ms
# 44:	learn: 0.9384239	total: 1.56s	remaining: 173ms
# 45:	learn: 0.9378708	total: 1.6s	remaining: 139ms
# 46:	learn: 0.9376209	total: 1.63s	remaining: 104ms
# 47:	learn: 0.9365370	total: 1.67s	remaining: 69.4ms
# 48:	learn: 0.9361443	total: 1.71s	remaining: 34.8ms
# 49:	learn: 0.9357684	total: 1.75s	remaining: 0us
# Average Accuracy: 0.33149598959676724

# %%
# Calculate the most frequent class
most_frequent_class = checkout_df['demand'].value_counts().idxmax()

count = checkout_df['demand'].value_counts()[most_frequent_class]
total = len(checkout_df)

guess_percent = count/total

guess_percent
# Out:
# 0.35875255765139463

# %%
# Calculate the most frequent class
most_frequent_class = checkout_df['demand'].value_counts().idxmax()

# Create a majority class baseline classifier
baseline_classifier = DummyClassifier(strategy="constant", constant=most_frequent_class)

# Perform 5-fold cross-validation
cross_val_predictions = cross_val_predict(baseline_classifier, checkout_df.drop(columns=['demand']), checkout_df['demand'], cv=5)

# Calculate classification report for cross-validation predictions
cross_val_performance = classification_report(checkout_df['demand'], cross_val_predictions)

# Calculate cross-validation accuracy scores
accuracy_scores = cross_val_score(baseline_classifier, checkout_df.drop(columns=['demand']), checkout_df['demand'], cv=5, scoring='accuracy')

# Calculate average accuracy
average_accuracy = accuracy_scores.mean()

# Print average accuracy and classification report
print("Average Accuracy:", average_accuracy)
print("Classification Report:")
print(cross_val_performance)
# Out:
# /Users/dannyxie/anaconda3/envs/catboost_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dannyxie/anaconda3/envs/catboost_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dannyxie/anaconda3/envs/catboost_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Baseline Majority Class Average Accuracy: 0.3587525576602992
#
# Classification Report for Cross-Validation:
#               precision    recall  f1-score   support
#
#         High       0.00      0.00      0.00    147268
#          Low       0.36      1.00      0.53    176385
#       Medium       0.00      0.00      0.00    168009
#
#     accuracy                           0.36    491662
#    macro avg       0.12      0.33      0.18    491662
# weighted avg       0.13      0.36      0.19    491662

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'max_depth': [None, 10, 20, 30],  # Define the range of tree depths to search
    'n_estimators': [50, 100, 200],  # Define the range of number of trees
    # Add other hyperparameters to tune if needed
}

# Create a Random Forest Classifier
rfc = RandomForestClassifier(random_state=0, verbose=True, n_jobs=-1)

# Create a GridSearchCV object
grid_search = GridSearchCV(rfc, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# Fit the grid search to the data
grid_search.fit(c_x, c_y)

# Get the best hyperparameters and the associated performance
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Cross-Validation Accuracy:", best_score)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   38.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   39.8s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   40.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   40.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   40.8s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.9s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   52.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   53.8s finished
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   54.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   56.1s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   56.8s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    5.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    1.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    4.6s finished
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    2.7s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    6.6s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:   11.3s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:   10.5s finished
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   40.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   42.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   40.9s
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   23.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   39.8s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.3s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.8min finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    7.4s finished
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   23.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   23.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   24.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   24.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  3.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  3.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  3.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   51.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.1s finished
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   53.0s finished
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   53.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  37 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.9s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    3.1s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:   20.4s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:   26.0s finished
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:   22.3s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  3.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  3.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:   11.3s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    3.6s finished
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   44.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   45.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  1.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    2.4s finished
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  1.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    2.2s finished
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  1.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    2.0s finished
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  1.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   38.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   38.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   37.8s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   34.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  1.2min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    1.1s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    1.9s finished
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   36.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.2min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.8s finished
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    3.2s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    1.4s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.5s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   42.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   42.7s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   56.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   57.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   58.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    4.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    3.2s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  2.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  2.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  2.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    9.6s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:   12.2s finished
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   45.8s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:   10.6s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   58.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    1.6s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   59.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  2.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    7.5s finished
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  2.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    3.0s finished
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   34.0s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   35.9s
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    4.0s finished
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   38.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   36.8s
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   39.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.6s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:   11.7s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.8min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:   10.6s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   48.1s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    6.5s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.8min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  3.0min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:   11.0s finished
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  2.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  2.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:   15.0s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:   14.3s finished
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  2.8min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    3.5s finished
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  2.0min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.6s
# Best Parameters: {'max_depth': 10, 'n_estimators': 50}
# Best Cross-Validation Accuracy: 0.3727092868728216
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    4.6s finished

# %%
from sklearn.model_selection import RandomizedSearchCV

# Define the parameter distribution
param_dist = {
    'max_depth': [3, 5, 7, 10],  # Define the range of tree depths to search
    'n_estimators': [50, 100, 150, 200],  # Define the range of number of trees
    # Add other hyperparameters to tune if needed
}

# Create an XGBoost Classifier
xgb_model = xgb.XGBClassifier(random_state=0, verbosity=1, n_jobs=-1)

# Create a RandomizedSearchCV object
random_search = RandomizedSearchCV(xgb_model, param_distributions=param_dist, n_iter=10, cv=5, scoring='accuracy', n_jobs=-1)

# Fit the random search to the data
random_search.fit(c_x, c_y_encoded)

# Get the best hyperparameters and the associated performance
best_params = random_search.best_params_
best_score = random_search.best_score_

print("Best Parameters:", best_params)
print("Best Cross-Validation Accuracy:", best_score)
# Out:
# Best Parameters: {'n_estimators': 50, 'max_depth': 3}
# Best Cross-Validation Accuracy: 0.3439395958923089

# %%
# Define the parameter distribution
param_dist = {
    'max_depth': [3, 5, 7, 10],  # Define the range of tree depths to search
    'iterations': [50, 100, 150, 200],  # Define the range of number of trees
    # Add other hyperparameters to tune if needed
}

# Create a CatBoost Classifier
catboost_model = CatBoostClassifier(random_state=0, verbose=0, thread_count=-1)

# Create a RandomizedSearchCV object
random_search = RandomizedSearchCV(catboost_model, param_distributions=param_dist, n_iter=10, cv=5, scoring='accuracy', n_jobs=-1)

# Fit the random search to the data
random_search.fit(c_x, c_y)

# Get the best hyperparameters and the associated performance
best_params = random_search.best_params_
best_score = random_search.best_score_

print("Best Parameters:", best_params)
print("Best Cross-Validation Accuracy:", best_score)
# Out:
# Best Parameters: {'max_depth': 3, 'iterations': 50}
# Best Cross-Validation Accuracy: 0.33149598959676724

# %%
# Return modeling

# %%
# Get X and Y
r_x = return_df.drop(columns=['demand']) # features
r_y = return_df['demand'] # target

# %%
# set up and train model
x_train, x_test, y_train, y_test = train_test_split(r_x, r_y, test_size=0.2, random_state=42)
return_rfc = RandomForestClassifier(n_estimators=50, max_depth=10, random_state = 0, verbose=True, n_jobs=-1)
return_rfc.fit(x_train, y_train)

# test model
y_prediction = return_rfc.predict(x_test)

# assess model performance
checkout_performance = classification_report(y_test, y_prediction)
print(checkout_performance)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    4.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.1s finished
#               precision    recall  f1-score   support
#
#         High       0.58      0.51      0.55     30120
#          Low       0.54      0.61      0.58     39376
#       Medium       0.40      0.39      0.40     37073
#
#     accuracy                           0.51    106569
#    macro avg       0.51      0.51      0.51    106569
# weighted avg       0.51      0.51      0.51    106569

# %%
# Export RFC Models
import joblib

# Export Checkout model
checkout_rfc_filename = 'checkout_rfc.pkl'
joblib.dump(checkout_rfc, checkout_rfc_filename)

# Export Return model
return_rfc_filename = 'return_rfc.pkl'
joblib.dump(return_rfc, return_rfc_filename)
# Out:
# ['return_rfc.pkl']
